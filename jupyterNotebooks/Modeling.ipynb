# %%
import pandas as pd
import numpy as np
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel

pd.pandas.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df=pd.read_csv('TrainingData.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'link', 'location', 'district', 'HouseType',
#        'total price', 'Update', 'Building', 'Object status',
#        'Location of the house', 'Home type', 'The floor', 'Built-up area',
#        'Usable area', 'Floor area', 'Land area', 'Garden area', 'Store',
#        'Move-in date', 'Water', 'Heating', 'Gas', 'Garbage', 'Transport',
#        'Communication', 'Energy efficiency of the building', 'Barrier-free',
#        'Equipment', 'companyName', 'proximityIndex', 'Index', 'Note on price',
#        'Electricity', 'Indicator of energy efficiency of the building',
#        'Object location', 'Parking', 'Garage', 'Year of reconstruction',
#        'Lift', 'Year of approval', 'Telecommunication',
#        'Certificate of energy performance of the building', 'Swimming pool',
#        'Housing costs', 'Discounted', 'Original price', 'Condition',
#        'locationLat', 'locationLong', 'price', 'provize', 'právního', 'dph',
#        'poplatků', 'cena k jednání', 'Built-up areaNan', 'Floor areaNan',
#        'Land areaNan', 'Garden areaNan', 'Year of reconstructionNan',
#        'Year of approvalNan'],
#       dtype='object')

# %%
print(df.isnull().any(axis='index').any())
# Out:
# False

# %% [markdown]
# Checks if there are any missing values in any of the columns of the dataframe.

# %%
X = df.drop('price', axis='columns')
y = df.price

# %%
X = X.loc[:, [x for x in X.columns if x not in ['Index', 'Unnamed: 0', 'link', 'location']]]

# %%
categoricalFeatures = [feature for feature in X.columns if X[feature].dtypes == 'O']

# %%
categoricalFeatures
# Out:
# ['district',
#  'HouseType',
#  'total price',
#  'Update',
#  'Building',
#  'Object status',
#  'Location of the house',
#  'Home type',
#  'The floor',
#  'Store',
#  'Move-in date',
#  'Water',
#  'Heating',
#  'Gas',
#  'Garbage',
#  'Transport',
#  'Communication',
#  'Energy efficiency of the building',
#  'Barrier-free',
#  'Equipment',
#  'companyName',
#  'Note on price',
#  'Electricity',
#  'Indicator of energy efficiency of the building',
#  'Object location',
#  'Parking',
#  'Garage',
#  'Lift',
#  'Telecommunication',
#  'Certificate of energy performance of the building',
#  'Swimming pool',
#  'Housing costs',
#  'Discounted',
#  'Original price',
#  'Condition',
#  'locationLat',
#  'locationLong',
#  'provize',
#  'právního',
#  'dph',
#  'poplatků',
#  'cena k jednání']

# %%
column_trans = make_column_transformer(
    (OneHotEncoder(), categoricalFeatures),
    remainder='passthrough')

# %%
#feature_sel_model = SelectFromModel(Lasso(alpha=0.005, random_state=0)) # remember to set the seed, the random state in this function
pipe = make_pipeline(column_trans, Lasso(alpha=0.005, random_state=0))
pipe.fit(X, y)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['district', 'HouseType',
#                                                    'total price', 'Update',
#                                                    'Building', 'Object status',
#                                                    'Location of the house',
#                                                    'Home type', 'The floor',
#                                                    'Store', 'Move-in date',
#                                                    'Water', 'Heating', 'Gas',
#                                                    'Garbage', 'Transport',
#                                                    'Communication',
#                                                    'Energy efficiency of the '
#                                                    'building',
#                                                    'Barrier-free', 'Equipment',
#                                                    'companyName',
#                                                    'Note on price',
#                                                    'Electricity',
#                                                    'Indicator of energy '
#                                                    'efficiency of the building',
#                                                    'Object location', 'Parking',
#                                                    'Garage', 'Lift',
#                                                    'Telecommunication',
#                                                    'Certificate of energy '
#                                                    'performance of the '
#                                                    'building', ...])])),
#                 ('lasso', Lasso(alpha=0.005, random_state=0))])

# %%
selected_feat = X.columns[(pipe.get_support())]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 selected_feat = X.columns[(pipe.get_support())]
#
# AttributeError: 'Pipeline' object has no attribute 'get_support'

# %%
# print('total features: {}'.format((X.shape[1])))
# print('selected features: {}'.format(len(selected_feat)))
