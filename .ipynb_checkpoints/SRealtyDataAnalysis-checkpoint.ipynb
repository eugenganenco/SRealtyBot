# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import ttest_ind
import re
from collections import Counter
import plotly.express as px
import json
from URL_helper import URL_helper

df = pd.read_csv('/Users/eugenganenco/Desktop/srealtyAnalysis/DataWithCoordPrice.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
np.seterr(divide = 'ignore') 
print(df.shape)
# Out:
# (5999, 72)

# %% [markdown]
# ### Analysis of the dependent variable 'price'

# %% [markdown]
# Because of the way I collected the data, every time a row has the price equal zero means that there was no value found.

# %%
def percentageMissing(feature):
    missingValues = df[feature].apply(lambda x: 1 if pd.isna(x) else 0).sum()
    return round((missingValues/len(df.axes[0])) * 100, 3)

data = df.copy()
missingValues = data.price.apply(lambda x: 1 if x == 0 else 0).sum()
percentageOfDf = round((missingValues/len(df.axes[0])) * 100, 3)
print('There are {} missing values in the dependent variable column. {}% of the data frame.'.format(missingValues, percentageOfDf))
# Out:
# There are 543 missing values in the dependent variable column. 9.052% of the data frame.

# %%
df = df.loc[df['price'] != 0]

# %% [markdown]
# I have eliminated all the instances where there was no value for the dependent variable.

# %%
print('Now the dependant variable has {}% missing.'.format(percentageMissing('price')))
# Out:
# Now the dependant variable has 0.0% missing.

# %%
print(f"Cheapest property found: {df['price'].min()} CZK")
print(f"Most expensive property found: {df['price'].max()} CZK")
# Out:
# Cheapest property found: 125000 CZK
# Most expensive property found: 129000000 CZK

# %%
df.price.describe()
# Out:
# count    5.456000e+03
# mean     7.276832e+06
# std      7.705617e+06
# min      1.250000e+05
# 25%      2.990000e+06
# 50%      5.025000e+06
# 75%      8.850200e+06
# max      1.290000e+08
# Name: price, dtype: float64

# %%
df.loc[df['price'] == df['price'].max(),['link', 'location']]
# Out:
#                                                                                                       link  \
# 3560  https://www.sreality.cz/detail/prodej/dum/undefined/praha-mala-strana-malostranske-namesti/737057116
#
#                                        location
# 3560  Malostranské náměstí, Praha - Malá Strana

# %%
df.loc[df['price'] == df['price'].min(),['link', 'location']]
# Out:
#                                                                                             link  \
# 3972  https://www.sreality.cz/detail/prodej/dum/chata/praha-horni-pocernice-nachodska/1943766604
#
#                                   location
# 3972  Náchodská, Praha 9 - Horní Počernice

# %% [markdown]
# These are the most expensive and the cheapest properties on the market respectively.

# %%
plt.hist(df['price'], bins=20)
plt.show()

# %% [markdown]
# The histogram above indicates a high degree of sqewness for the dependent variable. Could use some normalization.

# %%
_ = plt.boxplot(df['price'])

# %% [markdown]
# We notice a lot of outliers.

# %%
def getOutliersList(feature):
    featureList = np.array(df[feature].tolist())
    featureList = featureList[~np.isnan(featureList)]
    upperQuartile = np.percentile(featureList, 75)
    lowerQuartile = np.percentile(featureList, 25)
    IQR = (upperQuartile - lowerQuartile) * 1.5
    resultList = []
    for observation in featureList:
        if observation >= upperQuartile + IQR or observation <= lowerQuartile - IQR:
            resultList.append(observation)
    return resultList

print(f"There are {len(getOutliersList('price'))} outliers in the 'price' column.")
# Out:
# There are 373 outliers in the 'price' column.

# %% [markdown]
# ## Analysis of the independent variables

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Many columns are very sparsely populated. Cells painted with beige are null.

# %%
data = df.copy()
featureList = []
for feature in data.columns:
    if percentageMissing(feature) >= 90:
        featureList.append(feature)
print('The following features have more than 90% missing data:\n')
print(featureList)
# Out:
# The following features have more than 90% missing data:
#
# ['Indicator of energy efficiency of the building', 'Year of reconstruction', 'Cena', 'Year of approval', 'Certificate of energy performance of the building', 'Swimming pool', 'Number of flats', 'ID', 'Housing costs', 'Discounted', 'Original price', 'Pool area', 'Ceiling height', 'Condition', 'Soil construction', 'Starting price', 'Expert opinion', 'Minimum bid', 'Auction principal', 'Type of auction', 'Place of auction', 'The date of the auction', 'Auction decree', 'Expert opinion.1', 'Inspection date', 'Sale start date', 'Minimum purchase price', 'The date of the 1st inspection', 'The date of the 2nd inspection', 'Date of completion of construction', 'Inspection date to']

# %% [markdown]
# ### Relationship between missing variables and the dependent variable

# %%
featuresWithMissing = [feature for feature in df.columns if df[feature].isnull().sum() > 1]
for feature in featuresWithMissing:
    data = df.copy()
    data[feature] = np.where(data[feature].notnull(), 1, 0)
    data.groupby(feature)['price'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# There is a visible relationship between many of the missing values and the target variable.

# %% [markdown]
# ### Numerical variables

# %%
numbericalFeatures = [feature for feature in df.columns if df[feature].dtypes != 'O']

print('Number of numerical features is: {} out of {}.'.format(len(numbericalFeatures), len(df.columns)))
df[numbericalFeatures].head(5)
for feature in numbericalFeatures:
    print('Percentage of missin values for "{}" variabel is: {}'.format(feature,percentageMissing(feature)))
# Out:
# Number of numerical features is: 13 out of 72.
# Percentage of missin values for "Barrier-free" variabel is: 80.334
# Percentage of missin values for "proximityIndex" variabel is: 0.0
# Percentage of missin values for "Index" variabel is: 0.0
# Percentage of missin values for "Parking" variabel is: 57.991
# Percentage of missin values for "Garage" variabel is: 67.742
# Percentage of missin values for "Year of reconstruction" variabel is: 90.158
# Percentage of missin values for "Lift" variabel is: 66.202
# Percentage of missin values for "Year of approval" variabel is: 93.493
# Percentage of missin values for "Swimming pool" variabel is: 93.548
# Percentage of missin values for "Number of flats" variabel is: 99.12
# Percentage of missin values for "ID" variabel is: 92.467
# Percentage of missin values for "Soil construction" variabel is: 98.552
# Percentage of missin values for "price" variabel is: 0.0

# %% [markdown]
# ### Relationship between year variables and price of houses

# %%
yearFeatures = [feature for feature in numbericalFeatures if 'yr' in feature.lower() or 'year' in feature.lower()]
print(yearFeatures)
# Out:
# ['Year of reconstruction', 'Year of approval']

# %%
for feature in yearFeatures:
    df.groupby(feature)['price'].median().plot(style='.')
    plt.xlabel(feature)
    plt.ylabel('price')
    plt.title(feature)
    plt.show()

# %% [markdown]
# These are the graphs with year features containning outliers.

# %%
for feature in yearFeatures:
    outlierList = getOutliersList(feature)
    featureSeries = df.loc[~df[feature].isin(outlierList), :].groupby(feature)['price'].median()
    sns.regplot(x=featureSeries.index, y=featureSeries)
    plt.show()
    print(df[feature].describe())
# Out:
# count      578.000000
# mean      2039.769896
# std        762.486456
# min          2.000000
# 25%       2009.000000
# 50%       2016.000000
# 75%       2021.000000
# max      20223.000000
# Name: Year of reconstruction, dtype: float64
# count     403.000000
# mean     2001.019851
# std        32.363292
# min      1800.000000
# 25%      1995.500000
# 50%      2011.000000
# 75%      2021.000000
# max      2024.000000
# Name: Year of approval, dtype: float64

# %% [markdown]
# These are the graphs we get when we eliminate the outliers.

# %% [markdown]
# ### Discrete variables

# %%
discreteVariables = [feature for feature in numbericalFeatures if len(df[feature].unique()) < 30 and feature not in yearFeatures]
print(discreteVariables)
# Out:
# ['Barrier-free', 'Parking', 'Lift', 'Swimming pool', 'Number of flats', 'Soil construction']

# %%
for feature in discreteVariables:
    data = df.copy()
    data.groupby(feature)['price'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('price')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Continuous features

# %%
continuousFeatures = [feature for feature in numbericalFeatures if feature not in discreteVariables + yearFeatures + ['Index', 'ID', 'price']]
print(continuousFeatures)
# Out:
# ['proximityIndex', 'Garage']

# %%
for feature in continuousFeatures:
    data = df.copy()
    data[feature].hist(bins=30)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.title(feature)
    plt.show()

# %%
for feature in continuousFeatures:
    data = df.copy()
    data[feature] = np.log(data[feature])
    data['price'] = np.log(data['price'])
    sns.regplot(x=data[feature], y=data['price'], line_kws={"color": "red"})
    plt.xlabel(feature)
    plt.ylabel('price')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Categorical features

# %%
categoricalFeatures = [feature for feature in df.columns if df[feature].dtypes == 'O']
print(categoricalFeatures)
# Out:
# ['link', 'location', 'district', 'HouseType', 'total price', 'Job ID', 'Update', 'Building', 'Object status', 'Location of the house', 'Home type', 'The floor', 'Built-up area', 'Usable area', 'Floor area', 'Land area', 'Garden area', 'Store', 'Move-in date', 'Water', 'Heating', 'Gas', 'Garbage', 'Transport', 'Communication', 'Energy efficiency of the building', 'Equipment', 'companyName', 'Note on price', 'Electricity', 'Indicator of energy efficiency of the building', 'Object location', 'Cena', 'Telecommunication', 'Certificate of energy performance of the building', 'Housing costs', 'Discounted', 'Original price', 'Pool area', 'Ceiling height', 'Condition', 'Starting price', 'Expert opinion', 'Minimum bid', 'Auction principal', 'Type of auction', 'Place of auction', 'The date of the auction', 'Auction decree', 'Expert opinion.1', 'Inspection date', 'Sale start date', 'Minimum purchase price', 'The date of the 1st inspection', 'The date of the 2nd inspection', 'Date of completion of construction', 'Inspection date to', 'locationLat', 'locationLong', 'id', 'provize', 'právního', 'dph', 'poplatků', 'cena k jednání']

# %%
for feature in categoricalFeatures:
    print('The feature is "{}". Number of categories are {}'.format(feature,len(df[feature].unique())))
# Out:
# The feature is "link". Number of categories are 5456
# The feature is "location". Number of categories are 3932
# The feature is "district". Number of categories are 61
# The feature is "HouseType". Number of categories are 8
# The feature is "total price". Number of categories are 1644
# The feature is "Job ID". Number of categories are 4924
# The feature is "Update". Number of categories are 167
# The feature is "Building". Number of categories are 7
# The feature is "Object status". Number of categories are 10
# The feature is "Location of the house". Number of categories are 5
# The feature is "Home type". Number of categories are 2
# The feature is "The floor". Number of categories are 47
# The feature is "Built-up area". Number of categories are 601
# The feature is "Usable area". Number of categories are 643
# The feature is "Floor area". Number of categories are 383
# The feature is "Land area". Number of categories are 2041
# The feature is "Garden area". Number of categories are 883
# The feature is "Store". Number of categories are 106
# The feature is "Move-in date". Number of categories are 41
# The feature is "Water". Number of categories are 8
# The feature is "Heating". Number of categories are 82
# The feature is "Gas". Number of categories are 4
# The feature is "Garbage". Number of categories are 22
# The feature is "Transport". Number of categories are 32
# The feature is "Communication". Number of categories are 35
# The feature is "Energy efficiency of the building". Number of categories are 29
# The feature is "Equipment". Number of categories are 4
# The feature is "companyName". Number of categories are 1227
# The feature is "Note on price". Number of categories are 1015
# The feature is "Electricity". Number of categories are 9
# The feature is "Indicator of energy efficiency of the building". Number of categories are 209
# The feature is "Object location". Number of categories are 8
# The feature is "Cena". Number of categories are 1
# The feature is "Telecommunication". Number of categories are 47
# The feature is "Certificate of energy performance of the building". Number of categories are 2
# The feature is "Housing costs". Number of categories are 96
# The feature is "Discounted". Number of categories are 210
# The feature is "Original price". Number of categories are 200
# The feature is "Pool area". Number of categories are 26
# The feature is "Ceiling height". Number of categories are 19
# The feature is "Condition". Number of categories are 3
# The feature is "Starting price". Number of categories are 1
# The feature is "Expert opinion". Number of categories are 1
# The feature is "Minimum bid". Number of categories are 1
# The feature is "Auction principal". Number of categories are 1
# The feature is "Type of auction". Number of categories are 1
# The feature is "Place of auction". Number of categories are 1
# The feature is "The date of the auction". Number of categories are 1
# The feature is "Auction decree". Number of categories are 1
# The feature is "Expert opinion.1". Number of categories are 1
# The feature is "Inspection date". Number of categories are 35
# The feature is "Sale start date". Number of categories are 57
# The feature is "Minimum purchase price". Number of categories are 1
# The feature is "The date of the 1st inspection". Number of categories are 1
# The feature is "The date of the 2nd inspection". Number of categories are 1
# The feature is "Date of completion of construction". Number of categories are 23
# The feature is "Inspection date to". Number of categories are 6
# The feature is "locationLat". Number of categories are 3865
# The feature is "locationLong". Number of categories are 3865
# The feature is "id". Number of categories are 53
# The feature is "provize". Number of categories are 2
# The feature is "právního". Number of categories are 2
# The feature is "dph". Number of categories are 2
# The feature is "poplatků". Number of categories are 2
# The feature is "cena k jednání". Number of categories are 2

# %%
data = df.copy()
categoricalFeatures = [feature for feature in data.columns if feature not in numbericalFeatures and len(data[feature].unique()) <= 35]
categoricalFeatures = categoricalFeatures[:-11]
for feature in categoricalFeatures:
    data.groupby(feature)['price'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('price')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### Map of the Czech Republic with the average price of property being sold per NUTS 4 region.

# %%
czechStates = json.load(open('geoJsonCZ.json', 'r'))
czechStates['features'][0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[14.56924461704827, 50.00770879957661],
#     [14.534995811950823, 50.0114772445781],
#     [14.393345768303185, 49.952517282092586],
#     [14.345847384894167, 49.94727171895303],
#     [14.33880567277518, 49.98049139096107],
#     [14.296061152888404, 50.002024441137266],
#     [14.271127862446134, 50.03965596360334],
#     [14.25937514380102, 50.10043274550602],
#     [14.316258327373454, 50.12839885596487],
#     [14.359078279683196, 50.11598765248309],
#     [14.365589647853326, 50.1481991545729],
#     [14.401072379953709, 50.1479349371616],
#     [14.46673359236424, 50.16938602301883],
#     [14.533544563410173, 50.17686790571296],
#     [14.610808414188728, 50.12667002763059],
#     [14.658801088509474, 50.12282344095549],
#     [14.665945478445733, 50.103183216955685],
#     [14.706571427483144, 50.08722630297063],
#     [14.641226225810158, 50.05720943085254],
#     [14.66919214143369, 50.01927774803277],
#     [14.640195000385926, 50.00584355225821],
#     [14.56924461704827, 50.00770879957661]]]},
#  'properties': {'id': '3100',
#   'NUTS4': 'CZ0110',
#   'NUTS3': 'CZ011',
#   'NUTS2': 'CZ01',
#   'OB91': 1214174,
#   'OB00': 1180131,
#   'OB01': 1160118,
#   'FEA_TYPE': 'A001',
#   'name': 'Praha'},
#  'id': '3100'}

# %%
czechLocationsMap = {}
for feature in czechStates['features']:
    feature['id'] = feature['properties']['NUTS4']
    czechLocationsMap[feature['properties']['name']] = feature['id']

# %%
locationsSet = URL_helper().getLocations()
locationsSet.remove('Praha')
locationsSet.add('praha')

# %%
czechLocationsMap = {}
for feature in czechStates['features']:
    feature['id'] = feature['properties']['NUTS4']
    czechLocationsMap[feature['properties']['name']] = feature['id']

def findCorrespondingString(string, stringSet):
    if 'město' in string:
        string = string.replace('-město', '$')
    if ' n.' in string:
        string = string.replace(' n.', '-nad-') 
    charList = ['^']
    reg = re.compile(r'[a-zA-Z-]')
    for c in string:
        if c == '$':
            if charList[-1] == '*':
                charList = charList[0:len(charList)-1]
            break
        if reg.match(c):
            charList.append(c)
        else:
            charList.append('.')
            charList.append('*')
    if charList[-1] != '$':
        charList.append('$')
    string = ''.join(charList).lower()
    reg = re.compile(string)
    for s in stringSet:
        if reg.search(s.lower()):
            return s
    return 'Unknown'

for location in list(czechLocationsMap):
    # map location to the corresponding one in df
    val = czechLocationsMap[location]
    czechLocationsMap.pop(location)
    location = findCorrespondingString(location, locationsSet)
    czechLocationsMap[location] = val
    
print(czechLocationsMap)
print(len(locationsSet))
# Out:
# {'praha': 'CZ0110', 'benesov': 'CZ0211', 'beroun': 'CZ0212', 'kladno': 'CZ0213', 'kolin': 'CZ0214', 'kutna-hora': 'CZ0215', 'melnik': 'CZ0216', 'mlada-boleslav': 'CZ0217', 'nymburk': 'CZ0218', 'praha-vychod': 'CZ0219', 'praha-zapad': 'CZ021A', 'pribram': 'CZ021B', 'rakovnik': 'CZ021C', 'ceske-budejovice': 'CZ0311', 'cesky-krumlov': 'CZ0312', 'jindrichuv-hradec': 'CZ0313', 'pelhrimov': 'CZ0613', 'pisek': 'CZ0314', 'prachatice': 'CZ0315', 'strakonice': 'CZ0316', 'tabor': 'CZ0317', 'domazlice': 'CZ0321', 'cheb': 'CZ0411', 'karlovy-vary': 'CZ0412', 'klatovy': 'CZ0322', 'plzen': 'CZ0323', 'plzen-jih': 'CZ0324', 'plzen-sever': 'CZ0325', 'rokycany': 'CZ0326', 'sokolov': 'CZ0413', 'tachov': 'CZ0327', 'ceska-lipa': 'CZ0511', 'decin': 'CZ0421', 'chomutov': 'CZ0422', 'jablonec-nad-nisou': 'CZ0512', 'liberec': 'CZ0513', 'litomerice': 'CZ0423', 'louny': 'CZ0424', 'most': 'CZ0425', 'teplice': 'CZ0426', 'usti-nad-labem': 'CZ0427', 'havlickuv-brod': 'CZ0611', 'hradec-kralove': 'CZ0521', 'chrudim': 'CZ0531', 'jicin': 'CZ0522', 'nachod': 'CZ0523', 'pardubice': 'CZ0532', 'rychnov-nad-kneznou': 'CZ0524', 'semily': 'CZ0514', 'svitavy': 'CZ0533', 'trutnov': 'CZ0525', 'usti-nad-orlici': 'CZ0534', 'blansko': 'CZ0621', 'brno': 'CZ0622', 'brno-venkov': 'CZ0623', 'breclav': 'CZ0624', 'zlin': 'CZ0724', 'hodonin': 'CZ0625', 'jihlava': 'CZ0612', 'kromeriz': 'CZ0721', 'prostejov': 'CZ0713', 'trebic': 'CZ0614', 'uherske-hradiste': 'CZ0722', 'vyskov': 'CZ0626', 'znojmo': 'CZ0627', 'zdar-nad-sazavou': 'CZ0615', 'bruntal': 'CZ0811', 'frydek-mistek': 'CZ0812', 'karvina': 'CZ0813', 'novy-jicin': 'CZ0814', 'olomouc': 'CZ0712', 'opava': 'CZ0815', 'ostrava': 'CZ0816', 'prerov': 'CZ0714', 'sumperk': 'CZ0715', 'vsetin': 'CZ0723', 'jesenik': 'CZ0711'}
# 77

# %%
df['id'] = df['district'].apply(lambda x: czechLocationsMap['praha'] if bool(re.search(r'\d', x)) else czechLocationsMap[x])
len(df['id'].unique())
# Out:
# 53

# %%
data = df.groupby('id')['price'].apply(np.average)
data = data.to_frame()
data['N4'] = data.index
czechLocationsMapInversed = {v: k for k, v in czechLocationsMap.items()}
data['locationName'] = data['N4'].map(czechLocationsMapInversed)
fig = px.choropleth(data, locations='N4', geojson=czechStates, color='price', hover_name='locationName')
fig.update_geos(fitbounds='locations', visible=False)
fig.show()
# Out:
# <div>                            <div id="455212dc-32b9-453f-9947-16bb4a2aa773" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("455212dc-32b9-453f-9947-16bb4a2aa773")) {                    Plotly.newPlot(                        "455212dc-32b9-453f-9947-16bb4a2aa773",                        [{"coloraxis":"coloraxis","geo":"geo","geojson":{"type":"FeatureCollection","features":[{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[14.56924461704827,50.00770879957661],[14.534995811950823,50.0114772445781],[14.393345768303185,49.952517282092586],[14.345847384894167,49.94727171895303],[14.33880567277518,49.98049139096107],[14.296061152888404,50.002024441137266],[14.271127862446134,50.03965596360334],[14.25937514380102,50.10043274550602],[14.316258327373454,50.12839885596487],[14.359078279683196,50.11598765248309],[14.365589647853326,50.1481991545729],[14.401072379953709,50.1479349371616],[14.46673359236424,50.16938602301883],[14.533544563410173,50.17686790571296],[14.610808414188728,50.12667002763059],[14.658801088509474,50.12282344095549],[14.665945478445733,50.103183216955685],[14.706571427483144,50.08722630297063],[14.641226225810158,50.05720943085254],[14.66919214143369,50.01927774803277],[14.640195000385926,50.00584355225821],[14.56924461704827,50.00770879957661]]]},"properties":{"id":"3100","NUTS4":"CZ0110","NUTS3":"CZ011","NUTS2":"CZ01","OB91":1214174,"OB00":1180131,"OB01":1160118,"FEA_TYPE":"A001","name":"Praha"},"id":"CZ0110"},{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[15.244859800286028,49.624428155790284],[15.212785100138335,49.61175587200145],[15.125368206346264,49.5999297015933],[15.103826606325278,49.607790048963054],[14.934621839858321,49.569313349991475],[14.931304238980056,49.5504595067708],[14.903302469639963,49.54426687350339],[14.874157830081778,49.58157406992599],[14.76332355737603,49.60975608243769],[14.727788154691277,49.59664781306537],[14.724266840818952,49.56092684583382],[14.65648896028058,49.52473770495979],[14.585016140317732,49.518916602510295],[14.561115370976598,49.5313450551361],[14.474226020088938,49.54509348288672],[14.449692549022293,49.5624923405357],[14.491470421081882,49.613848908011434],[14.53227026545722,49.67968794880434],[14.509050234607681,49.71336356663225],[14.444056368237321,49.71820684876215],[14.40202520413629,49.75121882581948],[14.41116532812081,49.786779523716824],[14.426246807000988,49.82342049241013],[14.531124314638618,49.85869938533688],[14.541668930079483,49.883999808236794],[14.584918616048096,49.87934289591978],[14.584165372453509,49.85683825735381],[14.651126553097573,49.86062771722799],[14.671092614414215,49.89012182826112],[14.704335326268362,49.87598845185954],[14.73916517785483,49.88469982986589],[14.779694308036746,49.87415940878465],[14.820971839847852,49.88827619977964],[14.904903435196251,49.89283525377661],[14.92111504268044,49.879597549020225],[14.916668034381065,49.84270421918714],[14.946690687172278,49.795495093313434],[15.002098402418259,49.79040400742373],[15.006497396026306,49.76911252919238],[15.063592023656701,49.74171645550308],[15.094528384930971,49.71488689288757],[15.17732347022225,49.696688880528605],[15.179257479011682,49.67604594175893],[15.234361411105224,49.6653123180148],[15.244859800286028,49.624428155790284]]]},"properties":{"id":"3201","NUTS4":"CZ0211","NUTS3":"CZ021","NUTS2":"CZ02","OB91":94419,"OB00":93601,"OB01":93082,"FEA_TYPE":"A001","name":"Bene\u0161ov"},"id":"CZ0211"},{"type":"Feature","geometry":{"type":"Polygon","coordinates":[[[13.816968781340574,49.755692689374996],[13.794935049991771,49.76964761521891],[13.789118438624389,49.801792321988806],[13.811966727572923,49.854646296387266],[13.835183743118098,49.86767349233557],[13.809989136500898,49.92741617713148],[13.8250 ...

# %%
df.loc[df.id == 'CZ0110', 'price'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Price distribution of properties sold in Prague.

# %%
totalValueSeries = df.groupby('companyName')['price'].sum().sort_values(ascending=False)
valueCompanies = totalValueSeries.head(5)
otherCompanies = totalValueSeries.tail(totalValueSeries.count() - 5).sum()
valueCompanies.loc['Other Companies'] = otherCompanies
print(valueCompanies)
plt.pie(valueCompanies)
plt.legend(valueCompanies.index, loc='best')
plt.show()
# Out:
# companyName
# M&M reality                 4574545579
# RE/MAX G8 Reality           1326935999
# Bidli                        837176098
# Broker Consulting, a.s.      757969972
# Svoboda & Williams           632128000
# Other Companies            31573641611
# Name: price, dtype: int64

# %% [markdown]
# These are the top companies in Czech Republic by the total value of the properties they are selling.

# %%
countSeries = df.groupby('companyName')['link'].count().sort_values(ascending=False)
print(countSeries.head(5))
countSeries.head(10).plot.bar()
# Out:
# companyName
# M&M reality                874
# RE/MAX G8 Reality          236
# Broker Consulting, a.s.    123
# Bidli                      122
# Fincentrum Reality          71
# Name: link, dtype: int64
# <AxesSubplot:xlabel='companyName'>

# %% [markdown]
# These are the top companies in Czech Republic by the number of the houses they are selling (assuming that every posting refers to a different property).

# %%
(totalValueSeries / countSeries).sort_values(ascending=False)
# Out:
# companyName
# RE/MAX Miramar             92420000.0
# V. I. P. Homes             53000000.0
# ALGON                      50617000.0
# 7k-REALITY                 42650000.0
# KKCG Real Estate           40282400.0
#                               ...
# FinPremium reality                0.0
# REMACH s.r.o.                     0.0
# FRYDMAR reality                   0.0
# Top domov                         0.0
# HOME 2M - Domy Senomaty           0.0
# Length: 1295, dtype: float64

# %% [markdown]
# These are top companies in Czech Republic by the average price of the property their are selling.

# %% [markdown]
# ## Below I will transform various features to make them usable for further analysis

# %% [markdown]
# ### 1. "Floor" variable:

# %%
df['The floor'].unique()
# Out:
# array(['3', nan, '2', '3 včetně 1 podzemního', '14',
#        '5 včetně 1 podzemního', '2 včetně 1 podzemního',
#        '4 včetně 1 podzemního', '1', '1 včetně 1 podzemního',
#        '2. podlaží z celkem 2', '4', '4 včetně 2 podzemních',
#        '1. podlaží z celkem 2',
#        '1. podlaží z celkem 4 včetně 1 podzemního',
#        '3. podlaží z celkem 3', '4. podlaží z celkem 4', '5',
#        '6 včetně 1 podzemního', '3 včetně 2 podzemních',
#        '2 včetně 2 podzemních', '2. podlaží z celkem 1',
#        '1. podlaží z celkem 1', '1. podlaží',
#        '1. podlaží z celkem 2 včetně 1 podzemního',
#        '3. podlaží z celkem 2',
#        '1. podlaží z celkem 1 včetně 1 podzemního',
#        '2. podlaží z celkem 3 včetně 1 podzemního',
#        '1. podlaží z celkem 3 včetně 1 podzemního',
#        '1 včetně 2 podzemních', '2. podlaží', '6 včetně 3 podzemních',
#        '1 podzemní', '1. podlaží z celkem 3', '2. podlaží z celkem 3',
#        '10', '3. podlaží', '2. podlaží z celkem 2 včetně 1 podzemního',
#        '4 včetně 4 podzemních',
#        '1. podlaží z celkem 2 včetně 2 podzemních', '76',
#        '22 včetně 1 podzemního',
#        '3. podlaží z celkem 3 včetně 1 podzemního',
#        '3. podlaží z celkem 4 včetně 1 podzemního',
#        '1. podlaží z celkem 4', '1100', '8 včetně 5 podzemních'],
#       dtype=object)

# %%
print('Percentage of rows with non-missing "The Floor" variable: {}'.format(percentageMissing('The floor')))
# Out:
# Percentage of rows with non-missing "The Floor" variable: 20.087

# %% [markdown]
# Users of the site "Srealty" do not use the field "Podlaži" in a consistent and predictable manner. Those who sell single-family homes use this variable to indicate the number of floors their property has, those who live in flats - the floor their flat is located.

# %% [markdown]
# ### 2. Build-up area, Usable area, Floor Area, Land Area, Garden Area variables

# %%
def extractInt(string):
    charList = []
    for c in string:
        if c.isdigit():
            charList.append(c)
        else:
            break
    return int("".join(charList))

featureList = ['Built-up area', 'Usable area', 'Floor area', 'Land area', 'Garden area']
featuresModified = df.loc[:,featureList].applymap(extractInt, na_action='ignore')

for feature in featureList:
    df[feature] = featuresModified[feature].values
print(df.loc[:,featureList])
# Out:
#       Built-up area  Usable area  Floor area  Land area  Garden area
# 0              44.0          180       130.0      180.0        136.0
# 1             117.0          158         NaN     1401.0          NaN
# 2              87.0          225       160.0      785.0        633.0
# 3               NaN          341         NaN      381.0        260.0
# 4             650.0          180       180.0     1893.0          NaN
# ...             ...          ...         ...        ...          ...
# 5994          129.0          240         NaN      324.0          NaN
# 5995          220.0          200         NaN     1303.0       1303.0
# 5996            NaN          100         NaN     1501.0          NaN
# 5997          119.0          119         NaN      626.0          NaN
# 5998         1000.0         1000      1000.0    28663.0          NaN
#
# [5999 rows x 5 columns]

# %%
corr = df.loc[:,featureList].corr()
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
for feature in featureList:
    data = df.copy()
    data[feature] = np.log(data[feature])
    data['price'] = np.log(data['price'])
    sns.regplot(x=data[feature], y=data['price'], line_kws={"color": "red"})
    plt.xlabel(feature)
    plt.ylabel('price')
    plt.title(feature)
    plt.show()

# %% [markdown]
# ### 3. "Store" variable.

# %%
print('Percentage of rows with non-missing "Store" variable: {}'.format(percentageMissing('Store')))
# Out:
# Percentage of rows with non-missing "Store" variable: 63.944

# %%
df['Storage area'] = df['Store'].apply(lambda x: x if x != '1' else '0') # 0 will mean unknown
df['Storage area'] = df['Storage area'].str.replace(r'\s.*', '', regex=True)
df['Store'] = df['Store'].notnull().astype('int')

# %%
print(df['Store'].head())
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: Store, dtype: int64

# %%
sns.regplot(x=pd.to_numeric(df['Storage area'], errors='coerce'), y=data['price'], line_kws={"color": "red"})
plt.xlabel('Storage area')
plt.ylabel('price')
plt.title('Storage area')
plt.show()

# %%
df.groupby('Store')['price'].median().plot.bar()
plt.title('Store')
plt.show()

# %% [markdown]
# Variable "Store" will indicate if the property has a storage unit. "Storage area" will denote the area of that storage unit if provided.

# %% [markdown]
# ### 4. Energy efficiency of the building variable

# %%
df['Energy efficiency of the building'] = df['Energy efficiency of the building'].map(lambda x: x[6], na_action='ignore')
print(df['Energy efficiency of the building'])
# Out:
# 0         G
# 1         C
# 2         G
# 3         G
# 4         G
#        ...
# 5994      G
# 5995      G
# 5996      G
# 5997    NaN
# 5998    NaN
# Name: Energy efficiency of the building, Length: 5999, dtype: object

# %%
df.groupby('Energy efficiency of the building')['price'].median().plot.bar()
plt.title('Energy efficiency of the building')
plt.show()

# %% [markdown]
# ### 5. Note on price variable

# %%
len(df['Note on price'].unique())
# Out:
# 1015

# %%
print('Percentage of rows with non-missing "Note on price" variable: {}'.format(percentageMissing('Note on price')))
# Out:
# Percentage of rows with non-missing "Note on price" variable: 47.636

# %%
notesDict = Counter()
notesList = df['Note on price'].tolist()
for note in notesList:
    if pd.isna(note):
        continue
    notesDict.update([string.lower().lstrip() for string in re.split(',|;|/.', note)])
print(notesDict)
# Out:
# Counter({'v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 609, 'včetně provize': 524, 'včetně právního servisu': 470, 'včetně poplatků': 227, 'včetně dph': 187, 'cena k jednání': 147, '+ provize rk': 73, 'včetně provize rk': 66, 'včetně provize a právního servisu': 58, 'cena včetně provize a právního servisu': 35, 'včetně provize rk a právního servisu': 31, 'na klíč': 22, 'vč. zákl. desky a dph': 22, 'včetně provize a právních služeb': 20, 'včetně právního servisu a provize rk': 19, 'cena včetně provize rk': 18, 'cena včetně 1% provize': 18, 'vč. provize rk': 17, 'včetně provize rk a kompletního právního servisu. . v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 17, 'bez poplatků': 15, 'cena včetně provize': 14, 'včetně poplatků a právního servisu': 14, 'lze financovat hypotečním úvěrem': 12, 'právního servisu': 12, 'cena včetně provize a právních služeb': 12, 'včetně provize rk a právních služeb': 12, 'vč. provize a právních služeb': 12, 'včetně provize a právního servisu.': 11, 'včetně právního servisu. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 10, 'provize rk': 10, '<selenium.webdriver.remote.webelement.webelement (session="b0aef8c843c065071dd06ffb944cafe0"': 10, 'advokátní úschovy': 10, 'vč. provize a právního servisu': 10, 'cena včetně provize rk a kompletního právního servisu. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 10, '- kč': 9, 'kupní cena včetně provize zprostředkovatele a právního servisu.': 9, 'vč. provize': 9, 'cena vč. provize rk': 9, 'včetně provize realitní kanceláře': 9, 'včetně právního servisu a provize': 9, 'k jednání': 9, 'cena včetně provize rk a právních služeb': 9, 'poplatků a právního servisu': 9, 'cena vč. právních služeb a provize rk': 8, 'včetně služeb a provize rk': 8, 'včetně provize rk a právního servisu. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 8, 'cena je včetně provize rk': 8, 'právního a finančního servisu': 8, '-': 7, 'včetně právního servisu a provize rk. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 7, 'cena je včetně provize rk. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 7, 'vč. dph': 7, 'kupní cena včetně právního servisu': 7, 'advokátní úschovy a odměny rk': 7, 'cena je včetně provize a veškerého právního servisu': 7, 'včetně právního servisu a provize rk.': 7, 'cena včetně provize a právních služeb.': 7, '': 6, 'cena včetně právního servisu a provize rk. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 6, 'včetně právních služeb': 6, 'výrazná sleva. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 6, 'cena je uvedena včetně kompletního právního servisu': 6, 'včetně realitního a právního servisu': 6, 'právního a hypotečního servisu': 6, 'včetně provize rk + právního servisu': 6, 'cena včetně právního servisu a provize rk': 5, 'informace v realitní kanceláři': 5, 'sleva': 5, 'dph': 5, 'cena je konečná': 5, 'dohoda možná': 5, 'cena vč. provize': 5, 'cena včetně právních služeb a provize rk': 5, 'cena je včetně provize a právního servisu.': 5, 'vč. advokátního servisu a úschovy': 5, 'cena včetně dph': 5, 'advokátní úschovu i provizi realitní kanceláře.': 5, 'bez dph': 4, 'vč. právního servisu a provize rk': 4, 'konečná cena včetně právních služeb a provize.': 4, 'včetně služeb rk': 4, 'vyvolávací cena': 4, 'včetně provize a právního servisu. v případě více zájemců může rk využít pro výběr kupujícího formu aukce.': 4, 'k osobnímu jednání': 4, 'včetně veškerých poplatků rk': 4, 'finančního a právního servisu': 4, 'cena včetně provize a advokátních služeb': 4, 'hypoteční úvěr vám zajistíme.': 4, 'včetně právních služeb a provize rk': 4, 'vč. real. a právního servisu': 4, 'cena včetně provize a kompletního právního servisu': 4, 'cena je včetně provize a služeb rk': 4, 'cena vč. provize a právních služeb': 4, 'cena k jednání.': 4, 'právníh ...

# %% [markdown]
# The dictionary above sorts the types of notes found in 'Note on price' variable by frequency of occurance.

# %%
df['Note on price'].fillna('Nothing', inplace=True)
df.loc[df['Note on price'].str.contains('poplatků', re.IGNORECASE), ['Note on price']]
# Out:
#                                                                                               Note on price
# 2                                      včetně DPH, včetně poplatků, včetně provize, včetně právního servisu
# 88                                 včetně poplatků, včetně provize, včetně právního servisu, cena k jednání
# 146                                včetně poplatků, včetně provize, včetně právního servisu, cena k jednání
# 161                     16 800 000, -, včetně DPH, včetně poplatků, včetně provize, včetně právního servisu
# 162   2 500 000, - + provize RD + DPH, včetně DPH, včetně poplatků, včetně provize, včetně právního servisu
# ...                                                                                                     ...
# 5907                                   včetně DPH, včetně poplatků, včetně provize, včetně právního servisu
# 5962                                                  bez poplatků, včetně provize, včetně právního servisu
# 5969                   včetně DPH, včetně poplatků, včetně provize, včetně právního servisu, cena k jednání
# 5977                                               včetně poplatků, včetně provize, včetně právního servisu
# 5982   Cena k jednání, včetně DPH, včetně poplatků, včetně provize, včetně právního servisu, cena k jednání
#
# [320 rows x 1 columns]

# %% [markdown]
# Next I will try to extract from the 'Note on price' variable the information about whether the house price includes comission, legal fees, vat, fees and if the price is negotiable.

# %%
def followsPattern(text, pattern):
        if re.search(pattern, text.lower().lstrip()):
            return True
        else:
            return False

notelist = ['provize', 'právního', 'dph', 'poplatků']
patternList = []

for note in notelist:
    patternList.append(re.compile('.*(včetně|\+)\s?.*{}.*'.format(note)))
patternList.append(re.compile('.*cena k jednání'))
notelist.append('cena k jednání')

for note,patternToFollow in zip(notelist,patternList):
    df[note] = df.loc[df['Note on price'].apply(followsPattern, pattern=patternToFollow),'Note on price'].map(lambda x: 'True', na_action='ignore')

# %%
for feature in notelist:
    data = df.copy()
    data[feature] = np.where(data[feature].notnull(), 1, 0)
    data.groupby(feature)['price'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# The interesting part here is that the houses where the price is negotiable (cena k jendnani) cost more than those that do not indicate the possibility of negotiation.

# %% [markdown]
# ### 6. Electricity variable

# %%
print(df['Electricity'].unique())
# Out:
# [nan '230V, 400V' '400V' '230V' '120V, 400V' '120V, 230V'
#  '120V, 230V, 400V' '120V' '230V,']

# %% [markdown]
# ### 6. "Lift" variable:

# %%
df.groupby('Lift')['Index'].count()
# Out:
# Lift
# 0.0    1826
# 1.0      18
# Name: Index, dtype: int64

# %%
df['Lift'].count()/len(df.axes[0])
# Out:
# 0.3379765395894428

# %% [markdown]
# Find how much different are the houses with 'lift = 1' from the median in term of price.

# %%
df.loc[df['Lift'] == 1.0, ['price']].describe()
# Out:
#               price
# count  1.800000e+01
# mean   3.387217e+07
# std    3.454411e+07
# min    2.990000e+06
# 25%    8.474250e+06
# 50%    2.450000e+07
# 75%    4.343750e+07
# max    1.290000e+08

# %%
# df.loc[df.education == '9th', 'education'].count()
df.loc[df['Lift'] == 1, 'Index'].count()
# Out:
# 18

# %%
dataWithLift = df.loc[df['Lift'] == 1.0, ['price']]
plt.hist(dataWithLift, bins=15)
plt.show()

print('Median price for all properties is: {}'.format(round(df['price'].mean())))
print('Median price for all properties with lift is: {}'.format(round(dataWithLift['price'].mean())))

# if the sample size is larger than 30, use Z-test.
if df.loc[df['Lift'] == 1, 'Index'].count() <= 30:
    stat, p = ttest_ind(dataWithLift, df['price'])
    print('p-value for t-test: {}'.format(p))
else:
    stat, p = ztest(dataWithLift, df['price']) 
    print('p-value for z-test: {}'.format(p))
# Out:
# Median price for all properties is: 7276832
# Median price for all properties with lift is: 33872167
# p-value for t-test: [5.4289645e-45]

# %% [markdown]
# Given the small p-value the difference between the means are statistically signifficant.
